# %%
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()

DATABASE_URL = os.getenv('DATABASE_URL')

engine = create_engine(DATABASE_URL)

# %%
import pandas as pd

states_df = pd.read_csv('states_table.csv')

# %%
states_df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
states_df.to_sql("states", engine, if_exists='replace', index=False)

# %%
pd.read_sql("states", engine).head()
# Out:
#        state_acc     state_name  id
# 0             NY       New York   1
# 1             CA     California   2
# 2  north america  north america   3
# 3             MA  Massachusetts   4
# 4             NJ     New Jersey   5

# %%
import psycopg2

conn = psycopg2.connect(DATABASE_URL, sslmode='require')
c = conn.cursor()
fetch_films = '''
SELECT *
FROM states
WHERE state_name LIKE 'N%';
'''
c.execute(fetch_films)
c.fetchall()
# Out:
# [('NY', 'New York', 1),
#  ('NJ', 'New Jersey', 5),
#  ('NC', 'North Carolina', 12),
#  ('NM', 'New Mexico', 27),
#  ('NH', 'New Hampshire', 33),
#  ('NV', 'Nevada', 39),
#  ('NE', 'Nebraska', 48),
#  ('ND', 'North Dakota', 55),
#  ('MP', 'Northern Mariana Islands', 60)]

# %%
c.close()

# %%
conn = psycopg2.connect(DATABASE_URL, sslmode='require')
c = conn.cursor()
fetch_states = '''
SELECT *
FROM states
WHERE state_name LIKE 'N%';
'''
c.execute(fetch_states)
c.fetchall()
# Out:
# [('NY', 'New York', 1),
#  ('NJ', 'New Jersey', 5),
#  ('NC', 'North Carolina', 12),
#  ('NM', 'New Mexico', 27),
#  ('NH', 'New Hampshire', 33),
#  ('NV', 'Nevada', 39),
#  ('NE', 'Nebraska', 48),
#  ('ND', 'North Dakota', 55),
#  ('MP', 'Northern Mariana Islands', 60)]

# %%
c.close()

# %%
articles_df = pd.read_csv('articles_table.csv')
articles_df
# Out:
#        Unnamed: 0                                                 id  \
# 0               0  nyt://article/00036db7-8494-5141-b0ac-414118ca...
# 1               1  nyt://article/00074f13-bb5f-57c0-80e2-df0921cc...
# 2               2  nyt://article/00170d27-c2ca-5d3a-8c05-f27721c3...
# 3               3  nyt://article/001c8c67-95ae-5f45-ad75-3df0948d...
# 4               4  nyt://article/00275cc0-a134-5bfc-8b8c-4a10273e...
# ...           ...                                                ...
# 16375       16375  nyt://interactive/fcdcebf0-82bc-552d-aa5f-c2b9...
# 16376       16376  nyt://interactive/fcf09ccb-97fa-5969-b16c-ea02...
# 16377       16377  nyt://interactive/fd06adec-58b2-53f5-863a-3f99...
# 16378       16378  nyt://interactive/fd614981-1ab1-5905-aa03-caa1...
# 16379       16379  nyt://interactive/fe9c4865-4d55-5625-9720-4181...
#
#         section                                           keywords  \
# 0          U.S.  ['russian', 'interference', '2016', 'us', 'ele...
# 1        Sports  ['uefa', 'champion', 'league', 'soccer', 'socc...
# 2          U.S.  ['presidential', 'election', '2020', 'postal',...
# 3          U.S.  ['election', 'senate', 'georgia', 'voting', 'v...
# 4          Arts  ['cave', 'nick', '1959-', 'art', 'school', 'ga...
# ...         ...                                                ...
# 16375  Magazine  ['quarantine', 'photography', 'geneva', 'switz...
# 16376      U.S.  ['family', 'family', 'life', 'coronavirus', '2...
# 16377      U.S.  ['absentee', 'voting', 'election', 'presidenti...
# 16378      U.S.  ['coronavirus', '2019-ncov', 'quarantine', 'ne...
# 16379   Opinion  ['census', 'trump', 'donald', 'census', 'burea...
#
#                                                 headline  month  day  \
# 0      Michael Flynn Moves to Withdraw Guilty Plea in...      1   15
# 1      The Champions League Returns With a Plan for E...      8   10
# 2      Democrats Fear Partisan Slant at Postal Servic...      9    9
# 3      Early Voting Numbers in Georgia Senate Races P...     12   30
# 4      Nick Cave’s Truth May Be Writ Large, but Is It...     11   11
# ...                                                  ...    ...  ...
# 16375  I'm Usually a Conflict Photographer. Now, I'm ...      5   16
# 16376          Dancing Six Feet Apart? They’d Rather Not     11   24
# 16377  Record-Setting Turnout: Tracking Early Voting ...      9   22
# 16378  Portraits From New Orleans: A Close-Knit City ...      4    3
# 16379  Trump’s Desperate Plan to Cut Short the Census...      9   23
#
#        debate_score  engagement_score
# 0          0.003568          0.001209
# 1          0.014916          0.000914
# 2          0.004646          0.001072
# 3          0.005864          0.001952
# 4          0.014191          0.001962
# ...             ...               ...
# 16375      0.018744          0.000079
# 16376      0.002672          0.000253
# 16377      0.003572          0.000214
# 16378      0.002090          0.000268
# 16379      0.005396          0.000960
#
# [16380 rows x 9 columns]

# %%
articles_df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
import numpy as np

articles_df['id'] = np.arange(1,len(articles_df)+1,1)

# %%
articles_df.head()
# Out:
#    id section                                           keywords  \
# 0   1    U.S.  ['russian', 'interference', '2016', 'us', 'ele...
# 1   2  Sports  ['uefa', 'champion', 'league', 'soccer', 'socc...
# 2   3    U.S.  ['presidential', 'election', '2020', 'postal',...
# 3   4    U.S.  ['election', 'senate', 'georgia', 'voting', 'v...
# 4   5    Arts  ['cave', 'nick', '1959-', 'art', 'school', 'ga...
#
#                                             headline  month  day  \
# 0  Michael Flynn Moves to Withdraw Guilty Plea in...      1   15
# 1  The Champions League Returns With a Plan for E...      8   10
# 2  Democrats Fear Partisan Slant at Postal Servic...      9    9
# 3  Early Voting Numbers in Georgia Senate Races P...     12   30
# 4  Nick Cave’s Truth May Be Writ Large, but Is It...     11   11
#
#    debate_score  engagement_score
# 0      0.003568          0.001209
# 1      0.014916          0.000914
# 2      0.004646          0.001072
# 3      0.005864          0.001952
# 4      0.014191          0.001962

# %%
articles_df.to_sql("articles", engine, if_exists='replace', index=False)
#pd.read_sql("articles", engine).head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-828fcaa7c410> in <module>
# ----> 1 articles_df.to_sql("articles", engine, if_exists='replace', index=False)
#       2 #pd.read_sql("articles", engine).head()
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2774         from pandas.io import sql
#    2775
# -> 2776         sql.to_sql(
#    2777             self,
#    2778             name,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1395
#    1396         try:
# -> 1397             table.insert(chunksize, method=method)
#    1398         except exc.SQLAlchemyError as err:
#    1399             # GH34431
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     829
#     830                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831                 exec_insert(conn, keys, chunk_iter)
#     832
#     833     def _query_iterator(
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     746         """
#     747         data = [dict(zip(keys, row)) for row in data_iter]
# --> 748         conn.execute(self.table.insert(), data)
#     749
#     750     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1512                 )
#    1513             else:
# -> 1514                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1515
#    1516         finally:
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/encodings/utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
c = conn.cursor()
fetch_articles = '''
SELECT *
FROM articles
WHERE section = 'World';
'''
c.execute(fetch_articles)
c.fetchall()
